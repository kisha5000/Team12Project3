# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
from sklearn.model_selection import train_test_split
import os

# %%
filepath = "./Data/3_ML_Dry_Run.csv"
df = pd.read_csv(filepath)
# df = pd.read_csv(os.path.join("Data", "Speed_Dating_Data_columns.csv"))
df
# Out:
#       gender  order  match  sim_int_pct  samerace  age_partner  race_partner  \
# 0          0      4      0         0.14         0         27.0           2.0
# 1          0      3      0         0.54         0         22.0           2.0
# 2          0     10      1         0.16         1         22.0           4.0
# 3          0      5      1         0.61         0         23.0           2.0
# 4          0      7      1         0.21         0         24.0           3.0
# ...      ...    ...    ...          ...       ...          ...           ...
# 8373       1      5      0         0.64         0         26.0           3.0
# 8374       1      4      0         0.71         0         24.0           6.0
# 8375       1     10      0        -0.46         0         29.0           3.0
# 8376       1     16      0         0.62         0         22.0           4.0
# 8377       1     15      0         0.01         0         22.0           4.0
#
#       pf_o_att  pref_sincerity  Pref_intell  ...  clubbing  reading   tv  \
# 0         35.0            20.0         20.0  ...       5.0      6.0  9.0
# 1         60.0             0.0          0.0  ...       5.0      6.0  9.0
# 2         19.0            18.0         19.0  ...       5.0      6.0  9.0
# 3         30.0             5.0         15.0  ...       5.0      6.0  9.0
# 4         30.0            10.0         20.0  ...       5.0      6.0  9.0
# ...        ...             ...          ...  ...       ...      ...  ...
# 8373      10.0            10.0         30.0  ...       9.0      8.0  3.0
# 8374      50.0            20.0         10.0  ...       9.0      8.0  3.0
# 8375      40.0            10.0         30.0  ...       9.0      8.0  3.0
# 8376      10.0            25.0         25.0  ...       9.0      8.0  3.0
# 8377      20.0            20.0         10.0  ...       9.0      8.0  3.0
#
#       theater  movies  concerts  music  shopping  yoga  exphappy_frm_spddting
# 0         1.0    10.0      10.0    9.0       8.0   1.0                    3.0
# 1         1.0    10.0      10.0    9.0       8.0   1.0                    3.0
# 2         1.0    10.0      10.0    9.0       8.0   1.0                    3.0
# 3         1.0    10.0      10.0    9.0       8.0   1.0                    3.0
# 4         1.0    10.0      10.0    9.0       8.0   1.0                    3.0
# ...       ...     ...       ...    ...       ...   ...                    ...
# 8373      7.0     9.0      10.0   10.0       7.0   3.0                   10.0
# 8374      7.0     9.0      10.0   10.0       7.0   3.0                   10.0
# 8375      7.0     9.0      10.0   10.0       7.0   3.0                   10.0
# 8376      7.0     9.0      10.0   10.0       7.0   3.0                   10.0
# 8377      7.0     9.0      10.0   10.0       7.0   3.0                   10.0
#
# [8378 rows x 54 columns]

# %%
df.groupby("gender").count()
# Out:
#         order  match  sim_int_pct  samerace  age_partner  race_partner  \
# gender
# 0        4184   4184         4105      4184         4155          4164
# 1        4194   4194         4115      4194         4119          4141
#
#         pf_o_att  pref_sincerity  Pref_intell  pref_fun  ...  clubbing  \
# gender                                                   ...
# 0           4164            4164         4164      4155  ...      4125
# 1           4125            4125         4125      4125  ...      4174
#
#         reading    tv  theater  movies  concerts  music  shopping  yoga  \
# gender
# 0          4125  4125     4125    4125      4125   4125      4125  4125
# 1          4174  4174     4174    4174      4174   4174      4174  4174
#
#         exphappy_frm_spddting
# gender
# 0                        4103
# 1                        4174
#
# [2 rows x 53 columns]

# %%
df2 = df.dropna()
df2 = pd.get_dummies(df2, columns = ["undergra"])

# %%
def string_to_number(val):
    return int(''.join(filter(str.isdigit, val)))

# %%
df2["mn_sat"] = df2["mn_sat"].map(string_to_number)

# %%
df2["tuition"] = df2["tuition"].map(string_to_number)

# %%
df2["income"] = df2["income"].map(string_to_number)

# %%
X = df2.drop(columns = 'match')
y = df2["match"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.8574766355140186

# %%
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
df2.dtypes
# Out:
# gender                                                  int64
# order                                                   int64
# match                                                   int64
# sim_int_pct                                           float64
# samerace                                                int64
# age_partner                                           float64
# race_partner                                          float64
# pf_o_att                                              float64
# pref_sincerity                                        float64
# Pref_intell                                           float64
# pref_fun                                              float64
# pref_ambiton                                          float64
# pref_shared_int                                       float64
# dec_partner                                             int64
# overall_attr_partner                                  float64
# sinc_of_partner                                       float64
# intel_of_partner                                      float64
# fun_of_partner                                        float64
# amb_of_partner                                        float64
# shar_of_partner                                       float64
# likeness_partner                                      float64
# partner_says_yes                                      float64
# met_before                                            float64
# age_subject                                           float64
# field_cd                                              float64
# mn_sat                                                  int64
# tuition                                                 int64
# race                                                  float64
# imprace                                               float64
# imprelig                                              float64
# income                                                  int64
# goal                                                  float64
# date                                                  float64
# go_out                                                float64
# career_c                                              float64
# sports                                                float64
# tvsports                                              float64
# exercise                                              float64
# dining                                                float64
# museums                                               float64
# art                                                   float64
# hiking                                                float64
# gaming                                                float64
# clubbing                                              float64
# reading                                               float64
# tv                                                    float64
# theater                                               float64
# movies                                                float64
# concerts                                              float64
# music                                                 float64
# shopping                                              float64
# yoga                                                  float64
# exphappy_frm_spddting                                 float64
# undergra_American University                            uint8
# undergra_Amherst College                                uint8
# undergra_Arizona State                                  uint8
# undergra_Augustana College                              uint8
# undergra_Barnard College                                uint8
# undergra_Bennington College                             uint8
# undergra_Binghamton University                          uint8
# undergra_Boston College                                 uint8
# undergra_Bowdoin College                                uint8
# undergra_Brandeis University                            uint8
# undergra_Brown                                          uint8
# undergra_Brown University                               uint8
# undergra_Bucknell University                            uint8
# undergra_CSUN                                           uint8
# undergra_Cal Berkeley                                   uint8
# undergra_Colgate University                             uint8
# undergra_Colorado State                                 uint8
# undergra_Columbia                                       uint8
# undergra_Columbia College                               uint8
# undergra_Columbia College, CU                           uint8
# undergra_Columbia University                            uint8
# undergra_ColumbiaU                                      uint8
# undergra_Connecticut College                            uint8
# undergra_Conneticut College                             uint8
# undergra_Cornell                                        uint8
# undergra_Cornell University                             uint8
# undergra_Dartmouth College                              uint8
# undergra_Duquesne University                            uint8
# undergra_Emory University                               uint8
# undergra_Florida International University               uint8
# undergra_Fordham University                             uint8
# undergra_GA Tech                                        uint8
# undergra_George Mason University                        uint8
# undergra_Georgetown                                     uint8
# undergra_Georgetown University                          uint8
# undergra_Hampshire College                              uint8
# undergra_Harvard                                        uint8
# undergra_Harvard College                                uint8
# undergra_Harvard University                             uint8
# undergra_Harvey Mudd College (Physics)                  uint8
# undergra_Holy Cross                                     uint8
# undergra_Holy Cross College                             uint8
# undergra_John Hopkins                                   uint8
# undergra_Kettering University / GMI                     uint8
# undergra_Lafayette College                              uint8
# undergra_Loyola College                                 uint8
# undergra_Loyola College in Maryland                     uint8
# undergra_MIT                                            uint8
# undergra_Mary Baldwin College                           uint8
# undergra_Miami University                               uint8
# undergra_Middlebury College                             uint8
# undergra_NYU                                            uint8
# undergra_New York University                            uint8
# undergra_Northwestern University                        uint8
# undergra_Notre Dame                                     uint8
# undergra_Oberlin College                                uint8
# undergra_Occidental College                             uint8
# undergra_PACE University                                uint8
# undergra_Penn State University                          uint8
# undergra_Princeton                                      uint8
# undergra_Princeton U.                                   uint8
# undergra_Princeton University                           uint8
# undergra_Purdue                                         uint8
# undergra_Queens College                                 uint8
# undergra_RPI                                            uint8
# undergra_Rice                                           uint8
# undergra_Rutgers College                                uint8
# undergra_Rutgers University                             uint8
# undergra_Rutgers University - New Brunswick             uint8
# undergra_SEAS                                           uint8
# undergra_SUNY Albany                                    uint8
# undergra_SUNY Binghamton                                uint8
# undergra_SUNY Geneseo                                   uint8
# undergra_SUNY Stony Brook                               uint8
# undergra_Saint Mary's College of California             uint8
# undergra_Santa Clara University                         uint8
# undergra_Sarah Lawrence College                         uint8
# undergra_Smith College                                  uint8
# undergra_Southwestern University                        uint8
# undergra_Stanford                                       uint8
# undergra_Stanford University                            uint8
# undergra_Swarthmore College                             uint8
# undergra_Syracuse University                            uint8
# undergra_Texas A&M                                      uint8
# undergra_The American University                        uint8
# undergra_Trinity College                                uint8
# undergra_U of  Michigan                                 uint8
# undergra_U of Vermont                                   uint8
# undergra_U.C. Berkeley                                  uint8
# undergra_UC Berkeley                                    uint8
# undergra_UC Davis                                       uint8
# undergra_UC Santa Cruz                                  uint8
# undergra_UC, IRVINE!!!!!!!!!                            uint8
# undergra_UCLA                                           uint8
# undergra_UCSB                                           uint8
# undergra_UPenn                                          uint8
# undergra_UW Madison                                     uint8
# undergra_Undeclared                                     uint8
# undergra_Univ of New Mexico                             uint8
# undergra_Univ of Pennsylvania                           uint8
# undergra_Univ. of Connecticut                           uint8
# undergra_Univeristy of California, Davis                uint8
# undergra_Univeristy of Michigan                         uint8
# undergra_University of Akron, OH                        uint8
# undergra_University of Arizona                          uint8
# undergra_University of California at Santa Barbara      uint8
# undergra_University of California at Santa Cruz         uint8
# undergra_University of Delaware                         uint8
# undergra_University of Florida                          uint8
# undergra_University of Maryland, and Oxford             uint8
# undergra_University of Michigan                         uint8
# undergra_University of Michigan-Ann Arbor               uint8
# undergra_University of North Carolina at Charlotte      uint8
# undergra_University of Oregon                           uint8
# undergra_University of Pennsylvania                     uint8
# undergra_University of Southern California              uint8
# undergra_University of Tennessee                        uint8
# undergra_University of Texas                            uint8
# undergra_University of Vermont                          uint8
# undergra_University of Washington                       uint8
# undergra_Wesleyan University                            uint8
# undergra_William and Mary                               uint8
# undergra_Yale                                           uint8
# undergra_Yale University                                uint8
# undergra_colby college, waterville, me                  uint8
# undergra_harvard                                        uint8
# undergra_marymount manhattan college                    uint8
# undergra_nyu                                            uint8
# undergra_oberlin                                        uint8
# undergra_u of southern california, economics            uint8
# undergra_ucla                                           uint8
# undergra_umass                                          uint8
# undergra_university of pennsylvania                     uint8
# undergra_wellesley college                              uint8
# dtype: object

# %%
importances = rf.feature_importances_
importances
# Out:
# array([4.44656942e-03, 2.52667729e-02, 3.04439366e-02, 6.09569568e-03,
#        2.17037299e-02, 1.33056312e-02, 2.27241812e-02, 2.34452398e-02,
#        2.09760378e-02, 2.20723173e-02, 2.20283520e-02, 2.35025473e-02,
#        1.28952670e-01, 3.10113526e-02, 1.73219626e-02, 1.66442233e-02,
#        2.96049487e-02, 1.69081997e-02, 2.82423866e-02, 3.42974900e-02,
#        3.33253098e-02, 1.11849414e-02, 1.62191651e-02, 1.63507739e-02,
#        1.07492592e-02, 1.04545523e-02, 8.74000059e-03, 1.44173233e-02,
#        1.15115269e-02, 1.64612907e-02, 8.70866035e-03, 1.29572279e-02,
#        8.80622561e-03, 1.21146522e-02, 1.40757335e-02, 1.36574394e-02,
#        1.47017065e-02, 1.05968710e-02, 1.16871675e-02, 1.23435661e-02,
#        1.36278434e-02, 1.29009938e-02, 1.43087011e-02, 1.15464781e-02,
#        1.24955378e-02, 1.26247471e-02, 1.10793042e-02, 1.51127839e-02,
#        1.36749534e-02, 1.36733242e-02, 1.35526255e-02, 1.28625146e-02,
#        1.14620190e-04, 4.10611318e-04, 1.43195407e-05, 3.43541148e-04,
#        2.63555286e-04, 1.37472541e-05, 4.07519943e-05, 1.12828257e-03,
#        1.46015012e-04, 1.84776835e-04, 3.45412467e-04, 3.14001943e-04,
#        7.17488551e-05, 2.51080289e-04, 7.99258008e-05, 8.43257986e-05,
#        2.76726705e-05, 4.25914842e-04, 1.31496514e-04, 4.78223295e-04,
#        2.18101332e-03, 1.35972310e-04, 1.17001735e-04, 2.10885567e-05,
#        6.31447545e-04, 2.55971856e-04, 7.12015140e-05, 2.45548425e-05,
#        1.65968021e-04, 5.25870032e-04, 1.05681482e-04, 2.68534231e-06,
#        1.35987630e-05, 2.05199680e-04, 2.31519021e-04, 6.33702470e-05,
#        9.09480993e-04, 3.15623687e-05, 1.24413553e-04, 1.63397262e-04,
#        5.75435761e-04, 7.96987663e-05, 1.17794443e-04, 0.00000000e+00,
#        1.82138373e-05, 7.11848531e-04, 2.43546148e-04, 1.10562677e-04,
#        6.94443654e-04, 1.69367192e-04, 5.89171827e-05, 1.10206201e-03,
#        9.23507540e-05, 3.45142308e-05, 1.95848783e-04, 5.69560181e-04,
#        7.00499223e-05, 1.01717756e-04, 1.92013820e-04, 1.92251902e-04,
#        1.74518313e-04, 6.24863121e-05, 8.12789022e-05, 5.36434820e-06,
#        1.58491392e-04, 1.18125680e-04, 5.14378810e-04, 4.17519963e-05,
#        2.71800219e-04, 1.04178329e-05, 3.13483197e-04, 7.59634567e-05,
#        2.92218819e-05, 0.00000000e+00, 5.88438631e-06, 9.48126742e-05,
#        7.19181656e-05, 1.01206141e-03, 1.55498490e-05, 1.20521120e-04,
#        4.06986849e-05, 1.57852770e-04, 6.40697494e-05, 1.92773670e-04,
#        7.02824816e-05, 8.06690149e-05, 1.85638746e-04, 7.87411693e-05,
#        1.37178813e-04, 1.17810674e-03, 7.01975967e-09, 2.50632774e-05,
#        4.50586676e-05, 2.24073788e-04, 0.00000000e+00, 6.74280064e-05,
#        4.02755083e-05, 3.43875123e-03, 3.11907084e-04, 3.70111004e-04,
#        8.12817259e-06, 2.17225815e-04, 3.37447640e-05, 1.21273073e-04,
#        5.14215413e-05, 5.12173090e-04, 0.00000000e+00, 4.86421199e-05,
#        1.49850090e-04, 2.63675326e-05, 4.59264090e-04, 1.89776222e-05,
#        4.31435263e-04, 7.66687239e-05, 3.68467210e-04, 5.17765634e-05,
#        1.73191492e-04, 2.42995675e-04, 3.69912932e-04, 5.48619986e-04,
#        3.41486376e-04, 3.05804819e-04, 1.53083778e-03, 3.39347076e-04,
#        5.58433683e-04, 3.34830671e-04, 2.87198587e-05, 1.29796673e-05,
#        0.00000000e+00, 7.37586024e-05, 6.86924097e-04, 1.72444796e-06,
#        9.86700657e-05, 1.90965417e-04])

# %%
sorted(zip(rf.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.12895266966562813, 'dec_partner'),
#  (0.03429749000939587, 'likeness_partner'),
#  (0.0333253097562175, 'partner_says_yes'),
#  (0.031011352617708144, 'overall_attr_partner'),
#  (0.0304439365939645, 'sim_int_pct'),
#  (0.02960494869028153, 'fun_of_partner'),
#  (0.02824238658477183, 'shar_of_partner'),
#  (0.025266772898221965, 'order'),
#  (0.023502547330462618, 'pref_shared_int'),
#  (0.023445239770100493, 'pref_sincerity'),
#  (0.022724181247115345, 'pf_o_att'),
#  (0.02207231728561787, 'pref_fun'),
#  (0.022028351963130594, 'pref_ambiton'),
#  (0.02170372988600945, 'age_partner'),
#  (0.020976037821792953, 'Pref_intell'),
#  (0.017321962627559823, 'sinc_of_partner'),
#  (0.016908199672567677, 'amb_of_partner'),
#  (0.016644223272408696, 'intel_of_partner'),
#  (0.016461290697992882, 'income'),
#  (0.0163507739103316, 'field_cd'),
#  (0.016219165058378313, 'age_subject'),
#  (0.015112783918479401, 'concerts'),
#  (0.014701706461210697, 'exercise'),
#  (0.014417323319192257, 'imprace'),
#  (0.014308701101373328, 'clubbing'),
#  (0.014075733546485588, 'sports'),
#  (0.013674953365707869, 'music'),
#  (0.013673324237607186, 'shopping'),
#  (0.013657439376509725, 'tvsports'),
#  (0.013627843400218288, 'hiking'),
#  (0.013552625461493396, 'yoga'),
#  (0.013305631171007429, 'race_partner'),
#  (0.012957227935832953, 'date'),
#  (0.01290099383207721, 'gaming'),
#  (0.012862514641077367, 'exphappy_frm_spddting'),
#  (0.012624747082194842, 'theater'),
#  (0.012495537832665288, 'tv'),
#  (0.012343566071020808, 'art'),
#  (0.012114652181107615, 'career_c'),
#  (0.01168716752746418, 'museums'),
#  (0.011546478136083732, 'reading'),
#  (0.011511526886146104, 'imprelig'),
#  (0.011184941434990386, 'met_before'),
#  (0.01107930422737515, 'movies'),
#  (0.010749259244352811, 'mn_sat'),
#  (0.010596870951107389, 'dining'),
#  (0.010454552331057153, 'tuition'),
#  (0.008806225608287383, 'go_out'),
#  (0.008740000590817148, 'race'),
#  (0.008708660350649888, 'goal'),
#  (0.006095695679578636, 'samerace'),
#  (0.00444656942173589, 'gender'),
#  (0.0034387512322154898, 'undergra_Undeclared'),
#  (0.0021810133220197497, 'undergra_Columbia University'),
#  (0.0015308377837529449, 'undergra_Yale'),
#  (0.0011781067398875904, 'undergra_UC Berkeley'),
#  (0.0011282825745461446, 'undergra_Boston College'),
#  (0.001102062007047043, 'undergra_NYU'),
#  (0.0010120614101025236, 'undergra_Smith College'),
#  (0.0009094809934412261, 'undergra_Harvard'),
#  (0.0007118485307908308, 'undergra_Loyola College'),
#  (0.0006944436539022585, 'undergra_Mary Baldwin College'),
#  (0.0006869240970714042, 'undergra_ucla'),
#  (0.0006314475453145516, 'undergra_Cornell'),
#  (0.0005754357609900104, 'undergra_Holy Cross'),
#  (0.0005695601806225255, 'undergra_Oberlin College'),
#  (0.00055843368315183, 'undergra_colby college, waterville, me'),
#  (0.0005486199861228432, 'undergra_University of Washington'),
#  (0.0005258700318008264, 'undergra_Florida International University'),
#  (0.0005143788100632572, 'undergra_Rutgers College'),
#  (0.0005121730900141509, 'undergra_University of California at Santa Barbara'),
#  (0.00047822329504110207, 'undergra_Columbia College, CU'),
#  (0.00045926408969855894, 'undergra_University of Michigan'),
#  (0.0004314352628575757, 'undergra_University of North Carolina at Charlotte'),
#  (0.0004259148420533372, 'undergra_Columbia'),
#  (0.0004106113181591392, 'undergra_Amherst College'),
#  (0.00037011100402952406, 'undergra_Univ of Pennsylvania'),
#  (0.00036991293212015387, 'undergra_University of Vermont'),
#  (0.00036846721002183324, 'undergra_University of Pennsylvania'),
#  (0.0003454124666724761, 'undergra_Brown'),
#  (0.0003435411476288639, 'undergra_Augustana College'),
#  (0.00034148637616325804, 'undergra_Wesleyan University'),
#  (0.0003393470757633373, 'undergra_Yale University'),
#  (0.00033483067067809405, 'undergra_harvard'),
#  (0.00031400194313961594, 'undergra_Brown University'),
#  (0.0003134831974725902, 'undergra_SUNY Albany'),
#  (0.00031190708446990134, 'undergra_Univ of New Mexico'),
#  (0.00030580481853819964, 'undergra_William and Mary'),
#  (0.00027180021946040123, 'undergra_Rutgers University - New Brunswick'),
#  (0.00026355528630994776, 'undergra_Barnard College'),
#  (0.0002559718558015907, 'undergra_Cornell University'),
#  (0.0002510802886642022, 'undergra_CSUN'),
#  (0.000243546148204903, 'undergra_Loyola College in Maryland'),
#  (0.0002429956748294781, 'undergra_University of Texas'),
#  (0.00023151902093285396, 'undergra_Georgetown University'),
#  (0.00022407378830496886, 'undergra_UCLA'),
#  (0.00021722581543898422, 'undergra_Univeristy of California, Davis'),
#  (0.00020519968009266332, 'undergra_Georgetown'),
#  (0.0001958487827407223, 'undergra_Notre Dame'),
#  (0.00019277366975194735, 'undergra_Texas A&M'),
#  (0.00019225190233031566, 'undergra_Princeton'),
#  (0.00019201381976027167, 'undergra_Penn State University'),
#  (0.00019096541696021036, 'undergra_wellesley college'),
#  (0.0001856387460938917, 'undergra_U of  Michigan'),
#  (0.00018477683503562013, 'undergra_Brandeis University'),
#  (0.0001745183127296005, 'undergra_Princeton U.'),
#  (0.0001731914919228406, 'undergra_University of Tennessee'),
#  (0.00016936719249273033, 'undergra_Miami University'),
#  (0.0001659680207834697, 'undergra_Emory University'),
#  (0.00016339726179169216, 'undergra_Harvey Mudd College (Physics)'),
#  (0.0001584913923709076, 'undergra_RPI'),
#  (0.00015785276954168105, 'undergra_Swarthmore College'),
#  (0.0001498500898717657, 'undergra_University of Florida'),
#  (0.0001460150119471374, 'undergra_Bowdoin College'),
#  (0.00013717881329732912, 'undergra_U.C. Berkeley'),
#  (0.0001359723098996437, 'undergra_ColumbiaU'),
#  (0.00013149651407853616, 'undergra_Columbia College'),
#  (0.00012441355327514128, 'undergra_Harvard University'),
#  (0.00012127307287311789, 'undergra_University of Akron, OH'),
#  (0.00012052111977623358, 'undergra_Stanford'),
#  (0.0001181256797274409, 'undergra_Rice'),
#  (0.00011779444281965156, 'undergra_John Hopkins'),
#  (0.00011700173516959657, 'undergra_Connecticut College'),
#  (0.00011462018969809863, 'undergra_American University'),
#  (0.00011056267673516219, 'undergra_MIT'),
#  (0.00010568148200923027, 'undergra_Fordham University'),
#  (0.00010171775571126275, 'undergra_PACE University'),
#  (9.867006571794392e-05, 'undergra_university of pennsylvania'),
#  (9.481267423417018e-05, 'undergra_Santa Clara University'),
#  (9.235075403313568e-05, 'undergra_New York University'),
#  (8.432579856513724e-05, 'undergra_Colgate University'),
#  (8.127890221866394e-05, 'undergra_Purdue'),
#  (8.066901494609134e-05, 'undergra_Trinity College'),
#  (7.992580081841218e-05, 'undergra_Cal Berkeley'),
#  (7.969876625424053e-05, 'undergra_Holy Cross College'),
#  (7.87411693038031e-05, 'undergra_U of Vermont'),
#  (7.666872388536962e-05, 'undergra_University of Oregon'),
#  (7.596345668708687e-05, 'undergra_SUNY Binghamton'),
#  (7.375860243870257e-05, 'undergra_u of southern california, economics'),
#  (7.191816561876138e-05, 'undergra_Sarah Lawrence College'),
#  (7.17488550988747e-05, 'undergra_Bucknell University'),
#  (7.120151403040243e-05, 'undergra_Dartmouth College'),
#  (7.028248157446396e-05, 'undergra_The American University'),
#  (7.004992228086417e-05, 'undergra_Occidental College'),
#  (6.74280064383158e-05, 'undergra_UPenn'),
#  (6.406974939411413e-05, 'undergra_Syracuse University'),
#  (6.337024695429936e-05, 'undergra_Hampshire College'),
#  (6.248631205747549e-05, 'undergra_Princeton University'),
#  (5.891718270201658e-05, 'undergra_Middlebury College'),
#  (5.177656338020229e-05, 'undergra_University of Southern California'),
#  (5.142154126654489e-05, 'undergra_University of Arizona'),
#  (4.8642119941813635e-05, 'undergra_University of Delaware'),
#  (4.505866763421137e-05, 'undergra_UC, IRVINE!!!!!!!!!'),
#  (4.175199628699505e-05, 'undergra_Rutgers University'),
#  (4.0751994294759946e-05, 'undergra_Binghamton University'),
#  (4.0698684933484925e-05, 'undergra_Stanford University'),
#  (4.0275508290237086e-05, 'undergra_UW Madison'),
#  (3.4514230807284365e-05, 'undergra_Northwestern University'),
#  (3.3744763985986176e-05, 'undergra_Univeristy of Michigan'),
#  (3.156236873899265e-05, 'undergra_Harvard College'),
#  (2.9221881909945615e-05, 'undergra_SUNY Geneseo'),
#  (2.871985874122482e-05, 'undergra_marymount manhattan college'),
#  (2.7672670500100536e-05, 'undergra_Colorado State'),
#  (2.6367532642309623e-05, 'undergra_University of Maryland, and Oxford'),
#  (2.5063277356096983e-05, 'undergra_UC Santa Cruz'),
#  (2.4554842467331203e-05, 'undergra_Duquesne University'),
#  (2.1088556682323477e-05, 'undergra_Conneticut College'),
#  (1.8977622218656032e-05, 'undergra_University of Michigan-Ann Arbor'),
#  (1.821383732775427e-05, 'undergra_Lafayette College'),
#  (1.554984903586629e-05, 'undergra_Southwestern University'),
#  (1.4319540736095633e-05, 'undergra_Arizona State'),
#  (1.3747254066811925e-05, 'undergra_Bennington College'),
#  (1.3598763009953531e-05, 'undergra_George Mason University'),
#  (1.2979667326973847e-05, 'undergra_nyu'),
#  (1.0417832871961824e-05, 'undergra_SEAS'),
#  (8.128172590494702e-06, 'undergra_Univ. of Connecticut'),
#  (5.884386309315365e-06, "undergra_Saint Mary's College of California"),
#  (5.364348198621148e-06, 'undergra_Queens College'),
#  (2.685342312459771e-06, 'undergra_GA Tech'),
#  (1.7244479580644675e-06, 'undergra_umass'),
#  (7.019759666518633e-09, 'undergra_UC Davis'),
#  (0.0, 'undergra_oberlin'),
#  (0.0, 'undergra_University of California at Santa Cruz'),
#  (0.0, 'undergra_UCSB'),
#  (0.0, 'undergra_SUNY Stony Brook'),
#  (0.0, 'undergra_Kettering University / GMI')]
