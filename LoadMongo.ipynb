# %%
#Import MongoDB and accessing the connection url (in config)

from config import Mongouri
import pymongo
import pandas as pd

# %%
# !pip install dnspython

# %%
#Connecting to MongoDB Atlas server.  Accessing the ML_Speed_Dating database

client = pymongo.MongoClient(Mongouri)
db = client.ML_Speed_Dating

# %%
#function to convert 3 columns from string to int
#mn_sat, tution, income

def string_to_number(val):
    return int(''.join(filter(str.isdigit, val)))

# %%
#reading in csv used to run ML and prepping to load into MongoDB
#convert to df, dropped NA
#mapped through 3 columns to ensure no string values

df = pd.read_csv("./Data/3_ML_Dry_Run.csv")
df = df.dropna()
df["mn_sat"] = df["mn_sat"].map(string_to_number)
df["tuition"] = df["tuition"].map(string_to_number)
df["income"] = df["income"].map(string_to_number)


df_list = df.to_dict("record")
df.head()
# Out:
#    gender  order  match  sim_int_pct  samerace  age_partner  race_partner  \
# 0       0      4      0         0.14         0         27.0           2.0
# 1       0      3      0         0.54         0         22.0           2.0
# 2       0     10      1         0.16         1         22.0           4.0
# 3       0      5      1         0.61         0         23.0           2.0
# 4       0      7      1         0.21         0         24.0           3.0
#
#    pf_o_att  pref_sincerity  Pref_intell  ...  clubbing  reading   tv  \
# 0      35.0            20.0         20.0  ...       5.0      6.0  9.0
# 1      60.0             0.0          0.0  ...       5.0      6.0  9.0
# 2      19.0            18.0         19.0  ...       5.0      6.0  9.0
# 3      30.0             5.0         15.0  ...       5.0      6.0  9.0
# 4      30.0            10.0         20.0  ...       5.0      6.0  9.0
#
#    theater  movies  concerts  music  shopping  yoga  exphappy_frm_spddting
# ...

# %%
#loading general data collection to MongoDB


for row in df_list:
    db.General_Data.insert_one(row)

# %%
#Prepping features of importance to load to MongoDB
#csv to df
#df to list of dict

df2 = pd.read_csv("./Data/Combined_features_Importance.csv")
df2_list = df2.to_dict("record")
df2.head()
# Out:
#    Feature_Percentage           Feature
# 0             36.0876       dec_partner
# 1              3.1789       sim_int_pct
# 2              2.6278  partner_says_yes
# 3              2.4799             order
# 4              2.1420    pref_sincerity

# %%
#loading combined features of importance to MongoDB

for row in df2_list:
    db.Combined_features_Importance.insert_one(row)

# %%
df_male = pd.read_csv("./Data/male_features_Importance.csv")
df_male_list = df_male.to_dict("record")
df_male.head()
# Out:
#    Feature_Percentage           Feature
# 0             45.1658       dec_partner
# 1              4.0391  partner_says_yes
# 2              2.5361       sim_int_pct
# 3              2.1072    pref_sincerity
# 4              2.0768       Pref_intell

# %%
df_female = pd.read_csv("./Data/female_features_Importance.csv")
df_female_list = df_female.to_dict("record")
df_female.head()
# Out:
#    Feature_Percentage           Feature
# 0             29.7900       dec_partner
# 1              3.7916       sim_int_pct
# 2              3.4763    pref_sincerity
# 3              3.2741             order
# 4              2.5715  partner_says_yes

# %%
#loading male features of importance to MongoDB

for row in df_male_list:
    db.Male_features_Importance.insert_one(row)

# %%
#loading female features of importance to MongoDB


for row in df_female_list:
    db.Female_features_Importance.insert_one(row)
